# %% [markdown]
# # ISSUE 84
# The following strategy has been adopted to respond to issue 84 concerning the data generation
#
# - Sample some chronic using regular expression (for training, validation, test and OOD test)
# - while the number of required observation is not reached:
#     - select a chronic by random among the pre-selected chronics
#     - Fast-forward or not to random time stamp
#     - Generate X time stamps from the time stamp identified in last step (e.g., 3 days)

# %%
import pathlib

# %%
LIPS_PATH = pathlib.Path().resolve().parent
CONFIG_PATH = LIPS_PATH / "configurations" / "powergrid" / "benchmarks" / "l2rpn_neurips_2020_track1_small.ini"
DATA_PATH = LIPS_PATH / "reference_data" / "test"
LOG_PATH = LIPS_PATH / "lips_logs.log"

# %%
if not DATA_PATH.exists():
    DATA_PATH.mkdir(mode=511, parents=False)

# %%
from lips.benchmark.powergridBenchmark import PowerGridBenchmark
benchmark1 = PowerGridBenchmark(benchmark_path=DATA_PATH, # set to None, to not store the data on disk
                                benchmark_name="Benchmark1",
                                load_data_set=False,
                                config_path=CONFIG_PATH,
                                log_path=LOG_PATH)
# Out:
# 2022-05-20 21:56:36.959348: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2022-05-20 21:56:36.959424: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.

# %% [markdown]
# **Generate the dataset by sampling <span style="color:red">one day</span> from each chronic in dataset.**
# The new argument `nb_samples_per_chronic` is added in generate function of `DataSet` class to manage the required number of time stamps per chronic. It is computed based on the number of time stamps, as there are one time stamp per 5 minutes, so one day it computed from :
#
# $$ \underbrace{1}_{\text{#days}} \times \underbrace{24}_{\text{#hours in day}} \times \underbrace{\frac{60}{5}}_{\text{#time stamps per hour}} = 288 \ \ \text{steps per day}$$

# %%
benchmark1.generate(nb_sample_train=int(1e5),
                    nb_sample_val=int(1e4),
                    nb_sample_test=int(1e4),
                    nb_sample_test_ood_topo=int(1e4)
                   )
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████| 100000/100000 [29:13<00:00, 57.01it/s]
# /home/milad/environments/lips/lib/python3.8/site-packages/numpy/lib/npyio.py:719: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   val = np.asanyarray(val)
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████| 10000/10000 [03:41<00:00, 45.20it/s]
# /home/milad/environments/lips/lib/python3.8/site-packages/numpy/lib/npyio.py:719: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   val = np.asanyarray(val)
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████| 10000/10000 [03:41<00:00, 45.23it/s]
# /home/milad/environments/lips/lib/python3.8/site-packages/numpy/lib/npyio.py:719: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   val = np.asanyarray(val)
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████| 10000/10000 [13:46<00:00, 12.11it/s]
# /home/milad/environments/lips/lib/python3.8/site-packages/numpy/lib/npyio.py:719: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   val = np.asanyarray(val)

# %% [markdown]
# We analyze, hereafter, the simulator used during the generation of dataset for training phase of the models.

# %%
print(len(benchmark1.training_simulator.chronics_name))
chronics_id_list = benchmark1.training_simulator.chronics_id 
chronics_names_list = benchmark1.training_simulator.chronics_name
chronics_names_unique = benchmark1.training_simulator.chronics_name_unique
time_stamps = benchmark1.training_simulator.time_stamps
# Out:
# 10000

# %% [markdown]
# These informations are also available using `chronics_info` variable of `DataSet` class.

# %%
chronics_id_list = benchmark1.train_dataset.chronics_info["chronics_id"]
chronics_names_list = benchmark1.train_dataset.chronics_info["chronics_name"]
chronics_names_unique = benchmark1.train_dataset.chronics_info["chronics_name_unique"]
time_stamps = benchmark1.train_dataset.chronics_info["time_stamps"]

# %%
print("Length of used chronics:", len(chronics_names_unique))
chronics_names_unique
# Out:
# Length of used chronics: 116
# ['Scenario_february_018',
#  'Scenario_may_015',
#  'Scenario_october_018',
#  'Scenario_july_001',
#  'Scenario_february_023',
#  'Scenario_june_022',
#  'Scenario_december_022',
#  'Scenario_april_012',
#  'Scenario_february_001',
#  'Scenario_march_004',
#  'Scenario_december_018',
#  'Scenario_september_021',
#  'Scenario_december_014',
#  'Scenario_june_019',
#  'Scenario_october_025',
#  'Scenario_march_002',
#  'Scenario_may_003',
#  'Scenario_january_003',
#  'Scenario_august_023',
#  'Scenario_february_026',
#  'Scenario_may_010',
#  'Scenario_april_013',
#  'Scenario_january_007',
#  'Scenario_may_011',
#  'Scenario_may_006',
#  'Scenario_january_018',
#  'Scenario_november_015',
#  'Scenario_march_009',
#  'Scenario_june_008',
#  'Scenario_december_007',
#  'Scenario_may_025',
#  'Scenario_february_006',
#  'Scenario_april_025',
#  'Scenario_december_012',
#  'Scenario_august_012',
#  'Scenario_june_023',
#  'Scenario_september_010',
#  'Scenario_december_025',
#  'Scenario_may_008',
#  'Scenario_march_029',
#  'Scenario_october_007',
#  'Scenario_january_026',
#  'Scenario_august_004',
#  'Scenario_march_015',
#  'Scenario_november_024',
#  'Scenario_july_007',
#  'Scenario_january_019',
#  'Scenario_january_003',
#  'Scenario_december_025',
#  'Scenario_november_019',
#  'Scenario_may_029',
#  'Scenario_december_013',
#  'Scenario_february_002',
#  'Scenario_june_000',
#  'Scenario_september_002',
#  'Scenario_june_000',
#  'Scenario_march_002',
#  'Scenario_july_015',
#  'Scenario_july_003',
#  'Scenario_august_023',
#  'Scenario_february_018',
#  'Scenario_february_004',
#  'Scenario_october_009',
#  'Scenario_july_011',
#  'Scenario_june_016',
#  'Scenario_june_023',
#  'Scenario_december_028',
#  'Scenario_september_029',
#  'Scenario_november_015',
#  'Scenario_october_007',
#  'Scenario_july_001',
#  'Scenario_january_025',
#  'Scenario_december_011',
#  'Scenario_february_004',
#  'Scenario_may_004',
#  'Scenario_august_012',
#  'Scenario_march_012',
#  'Scenario_september_013',
#  'Scenario_june_010',
#  'Scenario_february_029',
#  'Scenario_december_007',
#  'Scenario_june_025',
#  'Scenario_september_005',
#  'Scenario_october_004',
#  'Scenario_october_011',
#  'Scenario_march_017',
#  'Scenario_july_004',
#  'Scenario_december_007',
#  'Scenario_august_013',
#  'Scenario_march_024',
#  'Scenario_january_028',
#  'Scenario_may_008',
#  'Scenario_april_020',
#  'Scenario_november_000',
#  'Scenario_august_000',
#  'Scenario_october_012',
#  'Scenario_february_024',
#  'Scenario_december_015',
#  'Scenario_may_020',
#  'Scenario_october_003',
#  'Scenario_february_012',
#  'Scenario_october_011',
#  'Scenario_november_019',
#  'Scenario_february_005',
#  'Scenario_september_013',
#  'Scenario_august_007',
#  'Scenario_december_026',
#  'Scenario_january_007',
#  'Scenario_august_014',
#  'Scenario_december_026',
#  'Scenario_february_000',
#  'Scenario_february_019',
#  'Scenario_july_015',
#  'Scenario_july_008',
#  'Scenario_november_007',
#  'Scenario_october_010']

# %%
import numpy as np
print("Length of unique chronics used during the generation: ", len(np.unique(chronics_names_unique)))
# Out:
# Length of unique chronics used during the generation:  95

# %%
print("Number of items in time_stamps:", len(time_stamps))
# time_stamps
# Out:
# Number of items in time_stamps: 116

# %% [markdown]
# Time stamps for the first chronic. There should be time stamps for one entire day, as we have opted for `nb_samples_per_chronic=288`.

# %%
idx = 0
print("Time stamps for the chronic: ", chronics_names_unique[idx])
time_stamps[idx]
# Out:
# Time stamps for the chronic:  Scenario_february_018
# [datetime.datetime(2012, 2, 19, 17, 50),
#  datetime.datetime(2012, 2, 19, 17, 55),
#  datetime.datetime(2012, 2, 19, 18, 0),
#  datetime.datetime(2012, 2, 19, 18, 5),
#  datetime.datetime(2012, 2, 19, 18, 10),
#  datetime.datetime(2012, 2, 19, 18, 15),
#  datetime.datetime(2012, 2, 19, 18, 20),
#  datetime.datetime(2012, 2, 19, 18, 25),
#  datetime.datetime(2012, 2, 19, 18, 30),
#  datetime.datetime(2012, 2, 19, 18, 35),
#  datetime.datetime(2012, 2, 19, 18, 40),
#  datetime.datetime(2012, 2, 19, 18, 45),
#  datetime.datetime(2012, 2, 19, 18, 50),
#  datetime.datetime(2012, 2, 19, 18, 55),
#  datetime.datetime(2012, 2, 19, 19, 0),
#  datetime.datetime(2012, 2, 19, 19, 5),
#  datetime.datetime(2012, 2, 19, 19, 10),
#  datetime.datetime(2012, 2, 19, 19, 15),
#  datetime.datetime(2012, 2, 19, 19, 20),
#  datetime.datetime(2012, 2, 19, 19, 25),
#  datetime.datetime(2012, 2, 19, 19, 30),
#  datetime.datetime(2012, 2, 19, 19, 35),
#  datetime.datetime(2012, 2, 19, 19, 40),
#  datetime.datetime(2012, 2, 19, 19, 45),
#  datetime.datetime(2012, 2, 19, 19, 50),
#  datetime.datetime(2012, 2, 19, 19, 55),
#  datetime.datetime(2012, 2, 19, 20, 0),
#  datetime.datetime(2012, 2, 19, 20, 5),
#  datetime.datetime(2012, 2, 19, 20, 10),
#  datetime.datetime(2012, 2, 19, 20, 15),
#  datetime.datetime(2012, 2, 19, 20, 20),
#  datetime.datetime(2012, 2, 19, 20, 25),
#  datetime.datetime(2012, 2, 19, 20, 30),
#  datetime.datetime(2012, 2, 19, 20, 35),
#  datetime.datetime(2012, 2, 19, 20, 40),
#  datetime.datetime(2012, 2, 19, 20, 45),
#  datetime.datetime(2012, 2, 19, 20, 50),
#  datetime.datetime(2012, 2, 19, 20, 55),
#  datetime.datetime(2012, 2, 19, 21, 0),
#  datetime.datetime(2012, 2, 19, 21, 5),
#  datetime.datetime(2012, 2, 19, 21, 10),
#  datetime.datetime(2012, 2, 19, 21, 15),
#  datetime.datetime(2012, 2, 19, 21, 20),
#  datetime.datetime(2012, 2, 19, 21, 25),
#  datetime.datetime(2012, 2, 19, 21, 30),
#  datetime.datetime(2012, 2, 19, 21, 35),
#  datetime.datetime(2012, 2, 19, 21, 40),
#  datetime.datetime(2012, 2, 19, 21, 45),
#  datetime.datetime(2012, 2, 19, 21, 50),
#  datetime.datetime(2012, 2, 19, 21, 55),
#  datetime.datetime(2012, 2, 19, 22, 0),
#  datetime.datetime(2012, 2, 19, 22, 5),
#  datetime.datetime(2012, 2, 19, 22, 10),
#  datetime.datetime(2012, 2, 19, 22, 15),
#  datetime.datetime(2012, 2, 19, 22, 20),
#  datetime.datetime(2012, 2, 19, 22, 25),
#  datetime.datetime(2012, 2, 19, 22, 30),
#  datetime.datetime(2012, 2, 19, 22, 35),
#  datetime.datetime(2012, 2, 19, 22, 40),
#  datetime.datetime(2012, 2, 19, 22, 45),
#  datetime.datetime(2012, 2, 19, 22, 50),
#  datetime.datetime(2012, 2, 19, 22, 55),
#  datetime.datetime(2012, 2, 19, 23, 0),
#  datetime.datetime(2012, 2, 19, 23, 5),
#  datetime.datetime(2012, 2, 19, 23, 10),
#  datetime.datetime(2012, 2, 19, 23, 15),
#  datetime.datetime(2012, 2, 19, 23, 20),
#  datetime.datetime(2012, 2, 19, 23, 25),
#  datetime.datetime(2012, 2, 19, 23, 30),
#  datetime.datetime(2012, 2, 19, 23, 35),
#  datetime.datetime(2012, 2, 19, 23, 40),
#  datetime.datetime(2012, 2, 19, 23, 45),
#  datetime.datetime(2012, 2, 19, 23, 50),
#  datetime.datetime(2012, 2, 19, 23, 55),
#  datetime.datetime(2012, 2, 20, 0, 0),
#  datetime.datetime(2012, 2, 20, 0, 5),
#  datetime.datetime(2012, 2, 20, 0, 10),
#  datetime.datetime(2012, 2, 20, 0, 15),
#  datetime.datetime(2012, 2, 20, 0, 20),
#  datetime.datetime(2012, 2, 20, 0, 25),
#  datetime.datetime(2012, 2, 20, 0, 30),
#  datetime.datetime(2012, 2, 20, 0, 35),
#  datetime.datetime(2012, 2, 20, 0, 40),
#  datetime.datetime(2012, 2, 20, 0, 45),
#  datetime.datetime(2012, 2, 20, 0, 50),
#  datetime.datetime(2012, 2, 20, 0, 55),
#  datetime.datetime(2012, 2, 20, 1, 0),
#  datetime.datetime(2012, 2, 20, 1, 5),
#  datetime.datetime(2012, 2, 20, 1, 10),
#  datetime.datetime(2012, 2, 20, 1, 15),
#  datetime.datetime(2012, 2, 20, 1, 20),
#  datetime.datetime(2012, 2, 20, 1, 25),
#  datetime.datetime(2012, 2, 20, 1, 30),
#  datetime.datetime(2012, 2, 20, 1, 35),
#  datetime.datetime(2012, 2, 20, 1, 40),
#  datetime.datetime(2012, 2, 20, 1, 45),
#  datetime.datetime(2012, 2, 20, 1, 50),
#  datetime.datetime(2012, 2, 20, 1, 55),
#  datetime.datetime(2012, 2, 20, 2, 0),
#  datetime.datetime(2012, 2, 20, 2, 5),
#  datetime.datetime(2012, 2, 20, 2, 10),
#  datetime.datetime(2012, 2, 20, 2, 15),
#  datetime.datetime(2012, 2, 20, 2, 20),
#  datetime.datetime(2012, 2, 20, 2, 25),
#  datetime.datetime(2012, 2, 20, 2, 30),
#  datetime.datetime(2012, 2, 20, 2, 35),
#  datetime.datetime(2012, 2, 20, 2, 40),
#  datetime.datetime(2012, 2, 20, 2, 45),
#  datetime.datetime(2012, 2, 20, 2, 50),
#  datetime.datetime(2012, 2, 20, 2, 55),
#  datetime.datetime(2012, 2, 20, 3, 0),
#  datetime.datetime(2012, 2, 20, 3, 5),
#  datetime.datetime(2012, 2, 20, 3, 10),
#  datetime.datetime(2012, 2, 20, 3, 15),
#  datetime.datetime(2012, 2, 20, 3, 20),
#  datetime.datetime(2012, 2, 20, 3, 25),
#  datetime.datetime(2012, 2, 20, 3, 30),
#  datetime.datetime(2012, 2, 20, 3, 35),
#  datetime.datetime(2012, 2, 20, 3, 40),
#  datetime.datetime(2012, 2, 20, 3, 45),
#  datetime.datetime(2012, 2, 20, 3, 50),
#  datetime.datetime(2012, 2, 20, 3, 55),
#  datetime.datetime(2012, 2, 20, 4, 0),
#  datetime.datetime(2012, 2, 20, 4, 5),
#  datetime.datetime(2012, 2, 20, 4, 10),
#  datetime.datetime(2012, 2, 20, 4, 15),
#  datetime.datetime(2012, 2, 20, 4, 20),
#  datetime.datetime(2012, 2, 20, 4, 25),
#  datetime.datetime(2012, 2, 20, 4, 30),
#  datetime.datetime(2012, 2, 20, 4, 35),
#  datetime.datetime(2012, 2, 20, 4, 40),
#  datetime.datetime(2012, 2, 20, 4, 45),
#  datetime.datetime(2012, 2, 20, 4, 50),
#  datetime.datetime(2012, 2, 20, 4, 55),
#  datetime.datetime(2012, 2, 20, 5, 0),
#  datetime.datetime(2012, 2, 20, 5, 5),
#  datetime.datetime(2012, 2, 20, 5, 10),
#  datetime.datetime(2012, 2, 20, 5, 15),
#  datetime.datetime(2012, 2, 20, 5, 20),
#  datetime.datetime(2012, 2, 20, 5, 25),
#  datetime.datetime(2012, 2, 20, 5, 30),
#  datetime.datetime(2012, 2, 20, 5, 35),
#  datetime.datetime(2012, 2, 20, 5, 40),
#  datetime.datetime(2012, 2, 20, 5, 45),
#  datetime.datetime(2012, 2, 20, 5, 50),
#  datetime.datetime(2012, 2, 20, 5, 55),
#  datetime.datetime(2012, 2, 20, 6, 0),
#  datetime.datetime(2012, 2, 20, 6, 5),
#  datetime.datetime(2012, 2, 20, 6, 10),
#  datetime.datetime(2012, 2, 20, 6, 15),
#  datetime.datetime(2012, 2, 20, 6, 20),
#  datetime.datetime(2012, 2, 20, 6, 25),
#  datetime.datetime(2012, 2, 20, 6, 30),
#  datetime.datetime(2012, 2, 20, 6, 35),
#  datetime.datetime(2012, 2, 20, 6, 40),
#  datetime.datetime(2012, 2, 20, 6, 45),
#  datetime.datetime(2012, 2, 20, 6, 50),
#  datetime.datetime(2012, 2, 20, 6, 55),
#  datetime.datetime(2012, 2, 20, 7, 0),
#  datetime.datetime(2012, 2, 20, 7, 5),
#  datetime.datetime(2012, 2, 20, 7, 10),
#  datetime.datetime(2012, 2, 20, 7, 15),
#  datetime.datetime(2012, 2, 20, 7, 20),
#  datetime.datetime(2012, 2, 20, 7, 25),
#  datetime.datetime(2012, 2, 20, 7, 30),
#  datetime.datetime(2012, 2, 20, 7, 35),
#  datetime.datetime(2012, 2, 20, 7, 40),
#  datetime.datetime(2012, 2, 20, 7, 45),
#  datetime.datetime(2012, 2, 20, 7, 50),
#  datetime.datetime(2012, 2, 20, 7, 55),
#  datetime.datetime(2012, 2, 20, 8, 0),
#  datetime.datetime(2012, 2, 20, 8, 5),
#  datetime.datetime(2012, 2, 20, 8, 10),
#  datetime.datetime(2012, 2, 20, 8, 15),
#  datetime.datetime(2012, 2, 20, 8, 20),
#  datetime.datetime(2012, 2, 20, 8, 25),
#  datetime.datetime(2012, 2, 20, 8, 30),
#  datetime.datetime(2012, 2, 20, 8, 35),
#  datetime.datetime(2012, 2, 20, 8, 40),
#  datetime.datetime(2012, 2, 20, 8, 45),
#  datetime.datetime(2012, 2, 20, 8, 50),
#  datetime.datetime(2012, 2, 20, 8, 55),
#  datetime.datetime(2012, 2, 20, 9, 0),
#  datetime.datetime(2012, 2, 20, 9, 5),
#  datetime.datetime(2012, 2, 20, 9, 10),
#  datetime.datetime(2012, 2, 20, 9, 15),
#  datetime.datetime(2012, 2, 20, 9, 20),
#  datetime.datetime(2012, 2, 20, 9, 25),
#  datetime.datetime(2012, 2, 20, 9, 30),
#  datetime.datetime(2012, 2, 20, 9, 35),
#  datetime.datetime(2012, 2, 20, 9, 40),
#  datetime.datetime(2012, 2, 20, 9, 45),
#  datetime.datetime(2012, 2, 20, 9, 50),
#  datetime.datetime(2012, 2, 20, 9, 55),
#  datetime.datetime(2012, 2, 20, 10, 0),
#  datetime.datetime(2012, 2, 20, 10, 5),
#  datetime.datetime(2012, 2, 20, 10, 10),
#  datetime.datetime(2012, 2, 20, 10, 15),
#  datetime.datetime(2012, 2, 20, 10, 20),
#  datetime.datetime(2012, 2, 20, 10, 25),
#  datetime.datetime(2012, 2, 20, 10, 30),
#  datetime.datetime(2012, 2, 20, 10, 35),
#  datetime.datetime(2012, 2, 20, 10, 40),
#  datetime.datetime(2012, 2, 20, 10, 45),
#  datetime.datetime(2012, 2, 20, 10, 50),
#  datetime.datetime(2012, 2, 20, 10, 55),
#  datetime.datetime(2012, 2, 20, 11, 0),
#  datetime.datetime(2012, 2, 20, 11, 5),
#  datetime.datetime(2012, 2, 20, 11, 10),
#  datetime.datetime(2012, 2, 20, 11, 15),
#  datetime.datetime(2012, 2, 20, 11, 20),
#  datetime.datetime(2012, 2, 20, 11, 25),
#  datetime.datetime(2012, 2, 20, 11, 30),
#  datetime.datetime(2012, 2, 20, 11, 35),
#  datetime.datetime(2012, 2, 20, 11, 40),
#  datetime.datetime(2012, 2, 20, 11, 45),
#  datetime.datetime(2012, 2, 20, 11, 50),
#  datetime.datetime(2012, 2, 20, 11, 55),
#  datetime.datetime(2012, 2, 20, 12, 0),
#  datetime.datetime(2012, 2, 20, 12, 5),
#  datetime.datetime(2012, 2, 20, 12, 10),
#  datetime.datetime(2012, 2, 20, 12, 15),
#  datetime.datetime(2012, 2, 20, 12, 20),
#  datetime.datetime(2012, 2, 20, 12, 25),
#  datetime.datetime(2012, 2, 20, 12, 30),
#  datetime.datetime(2012, 2, 20, 12, 35),
#  datetime.datetime(2012, 2, 20, 12, 40),
#  datetime.datetime(2012, 2, 20, 12, 45),
#  datetime.datetime(2012, 2, 20, 12, 50),
#  datetime.datetime(2012, 2, 20, 12, 55),
#  datetime.datetime(2012, 2, 20, 13, 0),
#  datetime.datetime(2012, 2, 20, 13, 5),
#  datetime.datetime(2012, 2, 20, 13, 10),
#  datetime.datetime(2012, 2, 20, 13, 15),
#  datetime.datetime(2012, 2, 20, 13, 20),
#  datetime.datetime(2012, 2, 20, 13, 25),
#  datetime.datetime(2012, 2, 20, 13, 30),
#  datetime.datetime(2012, 2, 20, 13, 35),
#  datetime.datetime(2012, 2, 20, 13, 40),
#  datetime.datetime(2012, 2, 20, 13, 45),
#  datetime.datetime(2012, 2, 20, 13, 50),
#  datetime.datetime(2012, 2, 20, 13, 55),
#  datetime.datetime(2012, 2, 20, 14, 0),
#  datetime.datetime(2012, 2, 20, 14, 5),
#  datetime.datetime(2012, 2, 20, 14, 10),
#  datetime.datetime(2012, 2, 20, 14, 15),
#  datetime.datetime(2012, 2, 20, 14, 20),
#  datetime.datetime(2012, 2, 20, 14, 25),
#  datetime.datetime(2012, 2, 20, 14, 30),
#  datetime.datetime(2012, 2, 20, 14, 35),
#  datetime.datetime(2012, 2, 20, 14, 40),
#  datetime.datetime(2012, 2, 20, 14, 45),
#  datetime.datetime(2012, 2, 20, 14, 50),
#  datetime.datetime(2012, 2, 20, 14, 55),
#  datetime.datetime(2012, 2, 20, 15, 0),
#  datetime.datetime(2012, 2, 20, 15, 5),
#  datetime.datetime(2012, 2, 20, 15, 10),
#  datetime.datetime(2012, 2, 20, 15, 15),
#  datetime.datetime(2012, 2, 20, 15, 20),
#  datetime.datetime(2012, 2, 20, 15, 25),
#  datetime.datetime(2012, 2, 20, 15, 30),
#  datetime.datetime(2012, 2, 20, 15, 35),
#  datetime.datetime(2012, 2, 20, 15, 40),
#  datetime.datetime(2012, 2, 20, 15, 45),
#  datetime.datetime(2012, 2, 20, 15, 50),
#  datetime.datetime(2012, 2, 20, 15, 55),
#  datetime.datetime(2012, 2, 20, 16, 0),
#  datetime.datetime(2012, 2, 20, 16, 5),
#  datetime.datetime(2012, 2, 20, 16, 10),
#  datetime.datetime(2012, 2, 20, 16, 15),
#  datetime.datetime(2012, 2, 20, 16, 20),
#  datetime.datetime(2012, 2, 20, 16, 25),
#  datetime.datetime(2012, 2, 20, 16, 30),
#  datetime.datetime(2012, 2, 20, 16, 35),
#  datetime.datetime(2012, 2, 20, 16, 40),
#  datetime.datetime(2012, 2, 20, 16, 45),
#  datetime.datetime(2012, 2, 20, 16, 50),
#  datetime.datetime(2012, 2, 20, 16, 55),
#  datetime.datetime(2012, 2, 20, 17, 0),
#  datetime.datetime(2012, 2, 20, 17, 5),
#  datetime.datetime(2012, 2, 20, 17, 10),
#  datetime.datetime(2012, 2, 20, 17, 15),
#  datetime.datetime(2012, 2, 20, 17, 20),
#  datetime.datetime(2012, 2, 20, 17, 25),
#  datetime.datetime(2012, 2, 20, 17, 30),
#  datetime.datetime(2012, 2, 20, 17, 35),
#  datetime.datetime(2012, 2, 20, 17, 40),
#  datetime.datetime(2012, 2, 20, 17, 45),
#  datetime.datetime(2012, 2, 20, 17, 50),
#  datetime.datetime(2012, 2, 20, 17, 55),
#  datetime.datetime(2012, 2, 20, 18, 0),
#  datetime.datetime(2012, 2, 20, 18, 5),
#  datetime.datetime(2012, 2, 20, 18, 10),
#  datetime.datetime(2012, 2, 20, 18, 15),
#  datetime.datetime(2012, 2, 20, 18, 20),
#  datetime.datetime(2012, 2, 20, 18, 25),
#  datetime.datetime(2012, 2, 20, 18, 30),
#  datetime.datetime(2012, 2, 20, 18, 35),
#  datetime.datetime(2012, 2, 20, 18, 40),
#  datetime.datetime(2012, 2, 20, 18, 45),
#  datetime.datetime(2012, 2, 20, 18, 50),
#  datetime.datetime(2012, 2, 20, 18, 55),
#  datetime.datetime(2012, 2, 20, 19, 0),
#  datetime.datetime(2012, 2, 20, 19, 5),
#  datetime.datetime(2012, 2, 20, 19, 10),
#  datetime.datetime(2012, 2, 20, 19, 15),
#  datetime.datetime(2012, 2, 20, 19, 20),
#  datetime.datetime(2012, 2, 20, 19, 25),
#  datetime.datetime(2012, 2, 20, 19, 30),
#  datetime.datetime(2012, 2, 20, 19, 35),
#  datetime.datetime(2012, 2, 20, 19, 40),
#  datetime.datetime(2012, 2, 20, 19, 45),
#  datetime.datetime(2012, 2, 20, 19, 50),
#  datetime.datetime(2012, 2, 20, 19, 55),
#  datetime.datetime(2012, 2, 20, 20, 0),
#  datetime.datetime(2012, 2, 20, 20, 5),
#  datetime.datetime(2012, 2, 20, 20, 10),
#  datetime.datetime(2012, 2, 20, 20, 15),
#  datetime.datetime(2012, 2, 20, 20, 20),
#  datetime.datetime(2012, 2, 20, 20, 25),
#  datetime.datetime(2012, 2, 20, 20, 30),
#  datetime.datetime(2012, 2, 20, 20, 35),
#  datetime.datetime(2012, 2, 20, 20, 40),
#  datetime.datetime(2012, 2, 20, 20, 45),
#  datetime.datetime(2012, 2, 20, 20, 50),
#  datetime.datetime(2012, 2, 20, 20, 55),
#  datetime.datetime(2012, 2, 20, 21, 0),
#  datetime.datetime(2012, 2, 20, 21, 5),
#  datetime.datetime(2012, 2, 20, 21, 10),
#  datetime.datetime(2012, 2, 20, 21, 15),
#  datetime.datetime(2012, 2, 20, 21, 20),
#  datetime.datetime(2012, 2, 20, 21, 25),
#  datetime.datetime(2012, 2, 20, 21, 30),
#  datetime.datetime(2012, 2, 20, 21, 35),
#  datetime.datetime(2012, 2, 20, 21, 40),
#  datetime.datetime(2012, 2, 20, 21, 45),
#  datetime.datetime(2012, 2, 20, 21, 50),
#  datetime.datetime(2012, 2, 20, 21, 55),
#  datetime.datetime(2012, 2, 20, 22, 0),
#  datetime.datetime(2012, 2, 20, 22, 5),
#  datetime.datetime(2012, 2, 20, 22, 10),
#  datetime.datetime(2012, 2, 20, 22, 15),
#  datetime.datetime(2012, 2, 20, 22, 20),
#  datetime.datetime(2012, 2, 20, 22, 25),
#  datetime.datetime(2012, 2, 20, 22, 30),
#  datetime.datetime(2012, 2, 20, 22, 35),
#  datetime.datetime(2012, 2, 20, 22, 40),
#  datetime.datetime(2012, 2, 20, 22, 45),
#  datetime.datetime(2012, 2, 20, 22, 50),
#  datetime.datetime(2012, 2, 20, 22, 55),
#  datetime.datetime(2012, 2, 20, 23, 0),
#  datetime.datetime(2012, 2, 20, 23, 5),
#  datetime.datetime(2012, 2, 20, 23, 10),
#  datetime.datetime(2012, 2, 20, 23, 15),
#  datetime.datetime(2012, 2, 20, 23, 20),
#  datetime.datetime(2012, 2, 20, 23, 25),
#  datetime.datetime(2012, 2, 20, 23, 30),
#  datetime.datetime(2012, 2, 20, 23, 35),
#  datetime.datetime(2012, 2, 20, 23, 40),
#  datetime.datetime(2012, 2, 20, 23, 45),
#  datetime.datetime(2012, 2, 20, 23, 50),
#  datetime.datetime(2012, 2, 20, 23, 55),
#  datetime.datetime(2012, 2, 21, 0, 0),
#  datetime.datetime(2012, 2, 21, 0, 5),
#  datetime.datetime(2012, 2, 21, 0, 10),
#  datetime.datetime(2012, 2, 21, 0, 15),
#  datetime.datetime(2012, 2, 21, 0, 20),
#  datetime.datetime(2012, 2, 21, 0, 25),
#  datetime.datetime(2012, 2, 21, 0, 30),
#  datetime.datetime(2012, 2, 21, 0, 35),
#  datetime.datetime(2012, 2, 21, 0, 40),
#  datetime.datetime(2012, 2, 21, 0, 45),
#  datetime.datetime(2012, 2, 21, 0, 50),
#  datetime.datetime(2012, 2, 21, 0, 55),
#  datetime.datetime(2012, 2, 21, 1, 0),
#  datetime.datetime(2012, 2, 21, 1, 5),
#  datetime.datetime(2012, 2, 21, 1, 10),
#  datetime.datetime(2012, 2, 21, 1, 15),
#  datetime.datetime(2012, 2, 21, 1, 20),
#  datetime.datetime(2012, 2, 21, 1, 25),
#  datetime.datetime(2012, 2, 21, 1, 30),
#  datetime.datetime(2012, 2, 21, 1, 35),
#  datetime.datetime(2012, 2, 21, 1, 40),
#  datetime.datetime(2012, 2, 21, 1, 45),
#  datetime.datetime(2012, 2, 21, 1, 50),
#  datetime.datetime(2012, 2, 21, 1, 55),
#  datetime.datetime(2012, 2, 21, 2, 0),
#  datetime.datetime(2012, 2, 21, 2, 5),
#  datetime.datetime(2012, 2, 21, 2, 10),
#  datetime.datetime(2012, 2, 21, 2, 15),
#  datetime.datetime(2012, 2, 21, 2, 20),
#  datetime.datetime(2012, 2, 21, 2, 25),
#  datetime.datetime(2012, 2, 21, 2, 30),
#  datetime.datetime(2012, 2, 21, 2, 35),
#  datetime.datetime(2012, 2, 21, 2, 40),
#  datetime.datetime(2012, 2, 21, 2, 45),
#  datetime.datetime(2012, 2, 21, 2, 50),
#  datetime.datetime(2012, 2, 21, 2, 55),
#  datetime.datetime(2012, 2, 21, 3, 0),
#  datetime.datetime(2012, 2, 21, 3, 5),
#  datetime.datetime(2012, 2, 21, 3, 10),
#  datetime.datetime(2012, 2, 21, 3, 15),
#  datetime.datetime(2012, 2, 21, 3, 20),
#  datetime.datetime(2012, 2, 21, 3, 25),
#  datetime.datetime(2012, 2, 21, 3, 30),
#  datetime.datetime(2012, 2, 21, 3, 35),
#  datetime.datetime(2012, 2, 21, 3, 40),
#  datetime.datetime(2012, 2, 21, 3, 45),
#  datetime.datetime(2012, 2, 21, 3, 50),
#  datetime.datetime(2012, 2, 21, 3, 55),
#  datetime.datetime(2012, 2, 21, 4, 0),
#  datetime.datetime(2012, 2, 21, 4, 5),
#  datetime.datetime(2012, 2, 21, 4, 10),
#  datetime.datetime(2012, 2, 21, 4, 15),
#  datetime.datetime(2012, 2, 21, 4, 20),
#  datetime.datetime(2012, 2, 21, 4, 25),
#  datetime.datetime(2012, 2, 21, 4, 30),
#  datetime.datetime(2012, 2, 21, 4, 35),
#  datetime.datetime(2012, 2, 21, 4, 40),
#  datetime.datetime(2012, 2, 21, 4, 45),
#  datetime.datetime(2012, 2, 21, 4, 50),
#  datetime.datetime(2012, 2, 21, 4, 55),
#  datetime.datetime(2012, 2, 21, 5, 0),
#  datetime.datetime(2012, 2, 21, 5, 5),
#  datetime.datetime(2012, 2, 21, 5, 10),
#  datetime.datetime(2012, 2, 21, 5, 15),
#  datetime.datetime(2012, 2, 21, 5, 20),
#  datetime.datetime(2012, 2, 21, 5, 25),
#  datetime.datetime(2012, 2, 21, 5, 30),
#  datetime.datetime(2012, 2, 21, 5, 35),
#  datetime.datetime(2012, 2, 21, 5, 40),
#  datetime.datetime(2012, 2, 21, 5, 45),
#  datetime.datetime(2012, 2, 21, 5, 50),
#  datetime.datetime(2012, 2, 21, 5, 55),
#  datetime.datetime(2012, 2, 21, 6, 0),
#  datetime.datetime(2012, 2, 21, 6, 5),
#  datetime.datetime(2012, 2, 21, 6, 10),
#  datetime.datetime(2012, 2, 21, 6, 15),
#  datetime.datetime(2012, 2, 21, 6, 20),
#  datetime.datetime(2012, 2, 21, 6, 25),
#  datetime.datetime(2012, 2, 21, 6, 30),
#  datetime.datetime(2012, 2, 21, 6, 35),
#  datetime.datetime(2012, 2, 21, 6, 40),
#  datetime.datetime(2012, 2, 21, 6, 45),
#  datetime.datetime(2012, 2, 21, 6, 50),
#  datetime.datetime(2012, 2, 21, 6, 55),
#  datetime.datetime(2012, 2, 21, 7, 0),
#  datetime.datetime(2012, 2, 21, 7, 5),
#  datetime.datetime(2012, 2, 21, 7, 10),
#  datetime.datetime(2012, 2, 21, 7, 15),
#  datetime.datetime(2012, 2, 21, 7, 20),
#  datetime.datetime(2012, 2, 21, 7, 25),
#  datetime.datetime(2012, 2, 21, 7, 30),
#  datetime.datetime(2012, 2, 21, 7, 35),
#  datetime.datetime(2012, 2, 21, 7, 40),
#  datetime.datetime(2012, 2, 21, 7, 45),
#  datetime.datetime(2012, 2, 21, 7, 50),
#  datetime.datetime(2012, 2, 21, 7, 55),
#  datetime.datetime(2012, 2, 21, 8, 0),
#  datetime.datetime(2012, 2, 21, 8, 5),
#  datetime.datetime(2012, 2, 21, 8, 10),
#  datetime.datetime(2012, 2, 21, 8, 15),
#  datetime.datetime(2012, 2, 21, 8, 20),
#  datetime.datetime(2012, 2, 21, 8, 25),
#  datetime.datetime(2012, 2, 21, 8, 30),
#  datetime.datetime(2012, 2, 21, 8, 35),
#  datetime.datetime(2012, 2, 21, 8, 40),
#  datetime.datetime(2012, 2, 21, 8, 45),
#  datetime.datetime(2012, 2, 21, 8, 50),
#  datetime.datetime(2012, 2, 21, 8, 55),
#  datetime.datetime(2012, 2, 21, 9, 0),
#  datetime.datetime(2012, 2, 21, 9, 5),
#  datetime.datetime(2012, 2, 21, 9, 10),
#  datetime.datetime(2012, 2, 21, 9, 15),
#  datetime.datetime(2012, 2, 21, 9, 20),
#  datetime.datetime(2012, 2, 21, 9, 25),
#  datetime.datetime(2012, 2, 21, 9, 30),
#  datetime.datetime(2012, 2, 21, 9, 35),
#  datetime.datetime(2012, 2, 21, 9, 40),
#  datetime.datetime(2012, 2, 21, 9, 45),
#  datetime.datetime(2012, 2, 21, 9, 50),
#  datetime.datetime(2012, 2, 21, 9, 55),
#  datetime.datetime(2012, 2, 21, 10, 0),
#  datetime.datetime(2012, 2, 21, 10, 5),
#  datetime.datetime(2012, 2, 21, 10, 10),
#  datetime.datetime(2012, 2, 21, 10, 15),
#  datetime.datetime(2012, 2, 21, 10, 20),
#  datetime.datetime(2012, 2, 21, 10, 25),
#  datetime.datetime(2012, 2, 21, 10, 30),
#  datetime.datetime(2012, 2, 21, 10, 35),
#  datetime.datetime(2012, 2, 21, 10, 40),
#  datetime.datetime(2012, 2, 21, 10, 45),
#  datetime.datetime(2012, 2, 21, 10, 50),
#  datetime.datetime(2012, 2, 21, 10, 55),
#  datetime.datetime(2012, 2, 21, 11, 0),
#  datetime.datetime(2012, 2, 21, 11, 5),
#  datetime.datetime(2012, 2, 21, 11, 10),
#  datetime.datetime(2012, 2, 21, 11, 15),
#  datetime.datetime(2012, 2, 21, 11, 20),
#  datetime.datetime(2012, 2, 21, 11, 25),
#  datetime.datetime(2012, 2, 21, 11, 30),
#  datetime.datetime(2012, 2, 21, 11, 35),
#  datetime.datetime(2012, 2, 21, 11, 40),
#  datetime.datetime(2012, 2, 21, 11, 45),
#  datetime.datetime(2012, 2, 21, 11, 50),
#  datetime.datetime(2012, 2, 21, 11, 55),
#  datetime.datetime(2012, 2, 21, 12, 0),
#  datetime.datetime(2012, 2, 21, 12, 5),
#  datetime.datetime(2012, 2, 21, 12, 10),
#  datetime.datetime(2012, 2, 21, 12, 15),
#  datetime.datetime(2012, 2, 21, 12, 20),
#  datetime.datetime(2012, 2, 21, 12, 25),
#  datetime.datetime(2012, 2, 21, 12, 30),
#  datetime.datetime(2012, 2, 21, 12, 35),
#  datetime.datetime(2012, 2, 21, 12, 40),
#  datetime.datetime(2012, 2, 21, 12, 45),
#  datetime.datetime(2012, 2, 21, 12, 50),
#  datetime.datetime(2012, 2, 21, 12, 55),
#  datetime.datetime(2012, 2, 21, 13, 0),
#  datetime.datetime(2012, 2, 21, 13, 5),
#  datetime.datetime(2012, 2, 21, 13, 10),
#  datetime.datetime(2012, 2, 21, 13, 15),
#  datetime.datetime(2012, 2, 21, 13, 20),
#  datetime.datetime(2012, 2, 21, 13, 25),
#  datetime.datetime(2012, 2, 21, 13, 30),
#  datetime.datetime(2012, 2, 21, 13, 35),
#  datetime.datetime(2012, 2, 21, 13, 40),
#  datetime.datetime(2012, 2, 21, 13, 45),
#  datetime.datetime(2012, 2, 21, 13, 50),
#  datetime.datetime(2012, 2, 21, 13, 55),
#  datetime.datetime(2012, 2, 21, 14, 0),
#  datetime.datetime(2012, 2, 21, 14, 5),
#  datetime.datetime(2012, 2, 21, 14, 10),
#  datetime.datetime(2012, 2, 21, 14, 15),
#  datetime.datetime(2012, 2, 21, 14, 20),
#  datetime.datetime(2012, 2, 21, 14, 25),
#  datetime.datetime(2012, 2, 21, 14, 30),
#  datetime.datetime(2012, 2, 21, 14, 35),
#  datetime.datetime(2012, 2, 21, 14, 40),
#  datetime.datetime(2012, 2, 21, 14, 45),
#  datetime.datetime(2012, 2, 21, 14, 50),
#  datetime.datetime(2012, 2, 21, 14, 55),
#  datetime.datetime(2012, 2, 21, 15, 0),
#  datetime.datetime(2012, 2, 21, 15, 5),
#  datetime.datetime(2012, 2, 21, 15, 10),
#  datetime.datetime(2012, 2, 21, 15, 15),
#  datetime.datetime(2012, 2, 21, 15, 20),
#  datetime.datetime(2012, 2, 21, 15, 25),
#  datetime.datetime(2012, 2, 21, 15, 30),
#  datetime.datetime(2012, 2, 21, 15, 35),
#  datetime.datetime(2012, 2, 21, 15, 40),
#  datetime.datetime(2012, 2, 21, 15, 45),
#  datetime.datetime(2012, 2, 21, 15, 50),
#  datetime.datetime(2012, 2, 21, 15, 55),
#  datetime.datetime(2012, 2, 21, 16, 0),
#  datetime.datetime(2012, 2, 21, 16, 5),
#  datetime.datetime(2012, 2, 21, 16, 10),
#  datetime.datetime(2012, 2, 21, 16, 15),
#  datetime.datetime(2012, 2, 21, 16, 20),
#  datetime.datetime(2012, 2, 21, 16, 25),
#  datetime.datetime(2012, 2, 21, 16, 30),
#  datetime.datetime(2012, 2, 21, 16, 35),
#  datetime.datetime(2012, 2, 21, 16, 40),
#  datetime.datetime(2012, 2, 21, 16, 45),
#  datetime.datetime(2012, 2, 21, 16, 50),
#  datetime.datetime(2012, 2, 21, 16, 55),
#  datetime.datetime(2012, 2, 21, 17, 0),
#  datetime.datetime(2012, 2, 21, 17, 5),
#  datetime.datetime(2012, 2, 21, 17, 10),
#  datetime.datetime(2012, 2, 21, 17, 15),
#  datetime.datetime(2012, 2, 21, 17, 20),
#  datetime.datetime(2012, 2, 21, 17, 25),
#  datetime.datetime(2012, 2, 21, 17, 30),
#  datetime.datetime(2012, 2, 21, 17, 35),
#  datetime.datetime(2012, 2, 21, 17, 40),
#  datetime.datetime(2012, 2, 21, 17, 45),
#  datetime.datetime(2012, 2, 21, 17, 50),
#  datetime.datetime(2012, 2, 21, 17, 55),
#  datetime.datetime(2012, 2, 21, 18, 0),
#  datetime.datetime(2012, 2, 21, 18, 5),
#  datetime.datetime(2012, 2, 21, 18, 10),
#  datetime.datetime(2012, 2, 21, 18, 15),
#  datetime.datetime(2012, 2, 21, 18, 20),
#  datetime.datetime(2012, 2, 21, 18, 25),
#  datetime.datetime(2012, 2, 21, 18, 30),
#  datetime.datetime(2012, 2, 21, 18, 35),
#  datetime.datetime(2012, 2, 21, 18, 40),
#  datetime.datetime(2012, 2, 21, 18, 45),
#  datetime.datetime(2012, 2, 21, 18, 50),
#  datetime.datetime(2012, 2, 21, 18, 55),
#  datetime.datetime(2012, 2, 21, 19, 0),
#  datetime.datetime(2012, 2, 21, 19, 5),
#  datetime.datetime(2012, 2, 21, 19, 10),
#  datetime.datetime(2012, 2, 21, 19, 15),
#  datetime.datetime(2012, 2, 21, 19, 20),
#  datetime.datetime(2012, 2, 21, 19, 25),
#  datetime.datetime(2012, 2, 21, 19, 30),
#  datetime.datetime(2012, 2, 21, 19, 35),
#  datetime.datetime(2012, 2, 21, 19, 40),
#  datetime.datetime(2012, 2, 21, 19, 45),
#  datetime.datetime(2012, 2, 21, 19, 50),
#  datetime.datetime(2012, 2, 21, 19, 55),
#  datetime.datetime(2012, 2, 21, 20, 0),
#  datetime.datetime(2012, 2, 21, 20, 5),
#  datetime.datetime(2012, 2, 21, 20, 10),
#  datetime.datetime(2012, 2, 21, 20, 15),
#  datetime.datetime(2012, 2, 21, 20, 20),
#  datetime.datetime(2012, 2, 21, 20, 25),
#  datetime.datetime(2012, 2, 21, 20, 30),
#  datetime.datetime(2012, 2, 21, 20, 35),
#  datetime.datetime(2012, 2, 21, 20, 40),
#  datetime.datetime(2012, 2, 21, 20, 45),
#  datetime.datetime(2012, 2, 21, 20, 50),
#  datetime.datetime(2012, 2, 21, 20, 55),
#  datetime.datetime(2012, 2, 21, 21, 0),
#  datetime.datetime(2012, 2, 21, 21, 5),
#  datetime.datetime(2012, 2, 21, 21, 10),
#  datetime.datetime(2012, 2, 21, 21, 15),
#  datetime.datetime(2012, 2, 21, 21, 20),
#  datetime.datetime(2012, 2, 21, 21, 25),
#  datetime.datetime(2012, 2, 21, 21, 30),
#  datetime.datetime(2012, 2, 21, 21, 35),
#  datetime.datetime(2012, 2, 21, 21, 40),
#  datetime.datetime(2012, 2, 21, 21, 45),
#  datetime.datetime(2012, 2, 21, 21, 50),
#  datetime.datetime(2012, 2, 21, 21, 55),
#  datetime.datetime(2012, 2, 21, 22, 0),
#  datetime.datetime(2012, 2, 21, 22, 5),
#  datetime.datetime(2012, 2, 21, 22, 10),
#  datetime.datetime(2012, 2, 21, 22, 15),
#  datetime.datetime(2012, 2, 21, 22, 20),
#  datetime.datetime(2012, 2, 21, 22, 25),
#  datetime.datetime(2012, 2, 21, 22, 30),
#  datetime.datetime(2012, 2, 21, 22, 35),
#  datetime.datetime(2012, 2, 21, 22, 40),
#  datetime.datetime(2012, 2, 21, 22, 45),
#  datetime.datetime(2012, 2, 21, 22, 50),
#  datetime.datetime(2012, 2, 21, 22, 55),
#  datetime.datetime(2012, 2, 21, 23, 0),
#  datetime.datetime(2012, 2, 21, 23, 5),
#  datetime.datetime(2012, 2, 21, 23, 10),
#  datetime.datetime(2012, 2, 21, 23, 15),
#  datetime.datetime(2012, 2, 21, 23, 20),
#  datetime.datetime(2012, 2, 21, 23, 25),
#  datetime.datetime(2012, 2, 21, 23, 30),
#  datetime.datetime(2012, 2, 21, 23, 35),
#  datetime.datetime(2012, 2, 21, 23, 40),
#  datetime.datetime(2012, 2, 21, 23, 45),
#  datetime.datetime(2012, 2, 21, 23, 50),
#  datetime.datetime(2012, 2, 21, 23, 55),
#  datetime.datetime(2012, 2, 22, 0, 0),
#  datetime.datetime(2012, 2, 22, 0, 5),
#  datetime.datetime(2012, 2, 22, 0, 10),
#  datetime.datetime(2012, 2, 22, 0, 15),
#  datetime.datetime(2012, 2, 22, 0, 20),
#  datetime.datetime(2012, 2, 22, 0, 25),
#  datetime.datetime(2012, 2, 22, 0, 30),
#  datetime.datetime(2012, 2, 22, 0, 35),
#  datetime.datetime(2012, 2, 22, 0, 40),
#  datetime.datetime(2012, 2, 22, 0, 45),
#  datetime.datetime(2012, 2, 22, 0, 50),
#  datetime.datetime(2012, 2, 22, 0, 55),
#  datetime.datetime(2012, 2, 22, 1, 0),
#  datetime.datetime(2012, 2, 22, 1, 5),
#  datetime.datetime(2012, 2, 22, 1, 10),
#  datetime.datetime(2012, 2, 22, 1, 15),
#  datetime.datetime(2012, 2, 22, 1, 20),
#  datetime.datetime(2012, 2, 22, 1, 25),
#  datetime.datetime(2012, 2, 22, 1, 30),
#  datetime.datetime(2012, 2, 22, 1, 35),
#  datetime.datetime(2012, 2, 22, 1, 40),
#  datetime.datetime(2012, 2, 22, 1, 45),
#  datetime.datetime(2012, 2, 22, 1, 50),
#  datetime.datetime(2012, 2, 22, 1, 55),
#  datetime.datetime(2012, 2, 22, 2, 0),
#  datetime.datetime(2012, 2, 22, 2, 5),
#  datetime.datetime(2012, 2, 22, 2, 10),
#  datetime.datetime(2012, 2, 22, 2, 15),
#  datetime.datetime(2012, 2, 22, 2, 20),
#  datetime.datetime(2012, 2, 22, 2, 25),
#  datetime.datetime(2012, 2, 22, 2, 30),
#  datetime.datetime(2012, 2, 22, 2, 35),
#  datetime.datetime(2012, 2, 22, 2, 40),
#  datetime.datetime(2012, 2, 22, 2, 45),
#  datetime.datetime(2012, 2, 22, 2, 50),
#  datetime.datetime(2012, 2, 22, 2, 55),
#  datetime.datetime(2012, 2, 22, 3, 0),
#  datetime.datetime(2012, 2, 22, 3, 5),
#  datetime.datetime(2012, 2, 22, 3, 10),
#  datetime.datetime(2012, 2, 22, 3, 15),
#  datetime.datetime(2012, 2, 22, 3, 20),
#  datetime.datetime(2012, 2, 22, 3, 25),
#  datetime.datetime(2012, 2, 22, 3, 30),
#  datetime.datetime(2012, 2, 22, 3, 35),
#  datetime.datetime(2012, 2, 22, 3, 40),
#  datetime.datetime(2012, 2, 22, 3, 45),
#  datetime.datetime(2012, 2, 22, 3, 50),
#  datetime.datetime(2012, 2, 22, 3, 55),
#  datetime.datetime(2012, 2, 22, 4, 0),
#  datetime.datetime(2012, 2, 22, 4, 5),
#  datetime.datetime(2012, 2, 22, 4, 10),
#  datetime.datetime(2012, 2, 22, 4, 15),
#  datetime.datetime(2012, 2, 22, 4, 20),
#  datetime.datetime(2012, 2, 22, 4, 25),
#  datetime.datetime(2012, 2, 22, 4, 30),
#  datetime.datetime(2012, 2, 22, 4, 35),
#  datetime.datetime(2012, 2, 22, 4, 40),
#  datetime.datetime(2012, 2, 22, 4, 45),
#  datetime.datetime(2012, 2, 22, 4, 50),
#  datetime.datetime(2012, 2, 22, 4, 55),
#  datetime.datetime(2012, 2, 22, 5, 0),
#  datetime.datetime(2012, 2, 22, 5, 5),
#  datetime.datetime(2012, 2, 22, 5, 10),
#  datetime.datetime(2012, 2, 22, 5, 15),
#  datetime.datetime(2012, 2, 22, 5, 20),
#  datetime.datetime(2012, 2, 22, 5, 25),
#  datetime.datetime(2012, 2, 22, 5, 30),
#  datetime.datetime(2012, 2, 22, 5, 35),
#  datetime.datetime(2012, 2, 22, 5, 40),
#  datetime.datetime(2012, 2, 22, 5, 45),
#  datetime.datetime(2012, 2, 22, 5, 50),
#  datetime.datetime(2012, 2, 22, 5, 55),
#  datetime.datetime(2012, 2, 22, 6, 0),
#  datetime.datetime(2012, 2, 22, 6, 5),
#  datetime.datetime(2012, 2, 22, 6, 10),
#  datetime.datetime(2012, 2, 22, 6, 15),
#  datetime.datetime(2012, 2, 22, 6, 20),
#  datetime.datetime(2012, 2, 22, 6, 25),
#  datetime.datetime(2012, 2, 22, 6, 30),
#  datetime.datetime(2012, 2, 22, 6, 35),
#  datetime.datetime(2012, 2, 22, 6, 40),
#  datetime.datetime(2012, 2, 22, 6, 45),
#  datetime.datetime(2012, 2, 22, 6, 50),
#  datetime.datetime(2012, 2, 22, 6, 55),
#  datetime.datetime(2012, 2, 22, 7, 0),
#  datetime.datetime(2012, 2, 22, 7, 5),
#  datetime.datetime(2012, 2, 22, 7, 10),
#  datetime.datetime(2012, 2, 22, 7, 15),
#  datetime.datetime(2012, 2, 22, 7, 20),
#  datetime.datetime(2012, 2, 22, 7, 25),
#  datetime.datetime(2012, 2, 22, 7, 30),
#  datetime.datetime(2012, 2, 22, 7, 35),
#  datetime.datetime(2012, 2, 22, 7, 40),
#  datetime.datetime(2012, 2, 22, 7, 45),
#  datetime.datetime(2012, 2, 22, 7, 50),
#  datetime.datetime(2012, 2, 22, 7, 55),
#  datetime.datetime(2012, 2, 22, 8, 0),
#  datetime.datetime(2012, 2, 22, 8, 5),
#  datetime.datetime(2012, 2, 22, 8, 10),
#  datetime.datetime(2012, 2, 22, 8, 15),
#  datetime.datetime(2012, 2, 22, 8, 20),
#  datetime.datetime(2012, 2, 22, 8, 25),
#  datetime.datetime(2012, 2, 22, 8, 30),
#  datetime.datetime(2012, 2, 22, 8, 35),
#  datetime.datetime(2012, 2, 22, 8, 40),
#  datetime.datetime(2012, 2, 22, 8, 45),
#  datetime.datetime(2012, 2, 22, 8, 50),
#  datetime.datetime(2012, 2, 22, 8, 55),
#  datetime.datetime(2012, 2, 22, 9, 0),
#  datetime.datetime(2012, 2, 22, 9, 5),
#  datetime.datetime(2012, 2, 22, 9, 10),
#  datetime.datetime(2012, 2, 22, 9, 15),
#  datetime.datetime(2012, 2, 22, 9, 20),
#  datetime.datetime(2012, 2, 22, 9, 25),
#  datetime.datetime(2012, 2, 22, 9, 30),
#  datetime.datetime(2012, 2, 22, 9, 35),
#  datetime.datetime(2012, 2, 22, 9, 40),
#  datetime.datetime(2012, 2, 22, 9, 45),
#  datetime.datetime(2012, 2, 22, 9, 50),
#  datetime.datetime(2012, 2, 22, 9, 55),
#  datetime.datetime(2012, 2, 22, 10, 0),
#  datetime.datetime(2012, 2, 22, 10, 5),
#  datetime.datetime(2012, 2, 22, 10, 10),
#  datetime.datetime(2012, 2, 22, 10, 15),
#  datetime.datetime(2012, 2, 22, 10, 20),
#  datetime.datetime(2012, 2, 22, 10, 25),
#  datetime.datetime(2012, 2, 22, 10, 30),
#  datetime.datetime(2012, 2, 22, 10, 35),
#  datetime.datetime(2012, 2, 22, 10, 40),
#  datetime.datetime(2012, 2, 22, 10, 45),
#  datetime.datetime(2012, 2, 22, 10, 50),
#  datetime.datetime(2012, 2, 22, 10, 55),
#  datetime.datetime(2012, 2, 22, 11, 0),
#  datetime.datetime(2012, 2, 22, 11, 5),
#  datetime.datetime(2012, 2, 22, 11, 10),
#  datetime.datetime(2012, 2, 22, 11, 15),
#  datetime.datetime(2012, 2, 22, 11, 20),
#  datetime.datetime(2012, 2, 22, 11, 25),
#  datetime.datetime(2012, 2, 22, 11, 30),
#  datetime.datetime(2012, 2, 22, 11, 35),
#  datetime.datetime(2012, 2, 22, 11, 40),
#  datetime.datetime(2012, 2, 22, 11, 45),
#  datetime.datetime(2012, 2, 22, 11, 50),
#  datetime.datetime(2012, 2, 22, 11, 55),
#  datetime.datetime(2012, 2, 22, 12, 0),
#  datetime.datetime(2012, 2, 22, 12, 5),
#  datetime.datetime(2012, 2, 22, 12, 10),
#  datetime.datetime(2012, 2, 22, 12, 15),
#  datetime.datetime(2012, 2, 22, 12, 20),
#  datetime.datetime(2012, 2, 22, 12, 25),
#  datetime.datetime(2012, 2, 22, 12, 30),
#  datetime.datetime(2012, 2, 22, 12, 35),
#  datetime.datetime(2012, 2, 22, 12, 40),
#  datetime.datetime(2012, 2, 22, 12, 45),
#  datetime.datetime(2012, 2, 22, 12, 50),
#  datetime.datetime(2012, 2, 22, 12, 55),
#  datetime.datetime(2012, 2, 22, 13, 0),
#  datetime.datetime(2012, 2, 22, 13, 5),
#  datetime.datetime(2012, 2, 22, 13, 10),
#  datetime.datetime(2012, 2, 22, 13, 15),
#  datetime.datetime(2012, 2, 22, 13, 20),
#  datetime.datetime(2012, 2, 22, 13, 25),
#  datetime.datetime(2012, 2, 22, 13, 30),
#  datetime.datetime(2012, 2, 22, 13, 35),
#  datetime.datetime(2012, 2, 22, 13, 40),
#  datetime.datetime(2012, 2, 22, 13, 45),
#  datetime.datetime(2012, 2, 22, 13, 50),
#  datetime.datetime(2012, 2, 22, 13, 55),
#  datetime.datetime(2012, 2, 22, 14, 0),
#  datetime.datetime(2012, 2, 22, 14, 5),
#  datetime.datetime(2012, 2, 22, 14, 10),
#  datetime.datetime(2012, 2, 22, 14, 15),
#  datetime.datetime(2012, 2, 22, 14, 20),
#  datetime.datetime(2012, 2, 22, 14, 25),
#  datetime.datetime(2012, 2, 22, 14, 30),
#  datetime.datetime(2012, 2, 22, 14, 35),
#  datetime.datetime(2012, 2, 22, 14, 40),
#  datetime.datetime(2012, 2, 22, 14, 45),
#  datetime.datetime(2012, 2, 22, 14, 50),
#  datetime.datetime(2012, 2, 22, 14, 55),
#  datetime.datetime(2012, 2, 22, 15, 0),
#  datetime.datetime(2012, 2, 22, 15, 5),
#  datetime.datetime(2012, 2, 22, 15, 10),
#  datetime.datetime(2012, 2, 22, 15, 15),
#  datetime.datetime(2012, 2, 22, 15, 20),
#  datetime.datetime(2012, 2, 22, 15, 25),
#  datetime.datetime(2012, 2, 22, 15, 30),
#  datetime.datetime(2012, 2, 22, 15, 35),
#  datetime.datetime(2012, 2, 22, 15, 40),
#  datetime.datetime(2012, 2, 22, 15, 45),
#  datetime.datetime(2012, 2, 22, 15, 50),
#  datetime.datetime(2012, 2, 22, 15, 55),
#  datetime.datetime(2012, 2, 22, 16, 0),
#  datetime.datetime(2012, 2, 22, 16, 5),
#  datetime.datetime(2012, 2, 22, 16, 10),
#  datetime.datetime(2012, 2, 22, 16, 15),
#  datetime.datetime(2012, 2, 22, 16, 20),
#  datetime.datetime(2012, 2, 22, 16, 25),
#  datetime.datetime(2012, 2, 22, 16, 30),
#  datetime.datetime(2012, 2, 22, 16, 35),
#  datetime.datetime(2012, 2, 22, 16, 40),
#  datetime.datetime(2012, 2, 22, 16, 45),
#  datetime.datetime(2012, 2, 22, 16, 50),
#  datetime.datetime(2012, 2, 22, 16, 55),
#  datetime.datetime(2012, 2, 22, 17, 0),
#  datetime.datetime(2012, 2, 22, 17, 5),
#  datetime.datetime(2012, 2, 22, 17, 10),
#  datetime.datetime(2012, 2, 22, 17, 15),
#  datetime.datetime(2012, 2, 22, 17, 20),
#  datetime.datetime(2012, 2, 22, 17, 25),
#  datetime.datetime(2012, 2, 22, 17, 30),
#  datetime.datetime(2012, 2, 22, 17, 35),
#  datetime.datetime(2012, 2, 22, 17, 40),
#  datetime.datetime(2012, 2, 22, 17, 45)]

# %% [markdown]
# ### Load and read the data concerning chronics

# %%
from lips.benchmark.powergridBenchmark import PowerGridBenchmark
benchmark_test = PowerGridBenchmark(benchmark_path=DATA_PATH, # set to None, to not store the data on disk
                                    benchmark_name="Benchmark1",
                                    load_data_set=True,
                                    config_path=CONFIG_PATH,
                                    log_path=LOG_PATH)

# %%
benchmark_test.train_dataset.chronics_info

# %%
chronics_id_list = benchmark1.train_dataset.chronics_info["chronics_id"]
chronics_names_list = benchmark1.train_dataset.chronics_info["chronics_name"]
chronics_names_unique = benchmark1.train_dataset.chronics_info["chronics_name_unique"]
time_stamps = benchmark1.train_dataset.chronics_info["time_stamps"]

# %%
chronics_names_unique
# Out:
# ['Scenario_february_018',
#  'Scenario_may_015',
#  'Scenario_october_018',
#  'Scenario_july_001',
#  'Scenario_february_023',
#  'Scenario_june_022',
#  'Scenario_december_022',
#  'Scenario_april_012',
#  'Scenario_february_001',
#  'Scenario_march_004',
#  'Scenario_december_018',
#  'Scenario_september_021',
#  'Scenario_december_014',
#  'Scenario_june_019',
#  'Scenario_october_025',
#  'Scenario_march_002',
#  'Scenario_may_003',
#  'Scenario_january_003',
#  'Scenario_august_023',
#  'Scenario_february_026',
#  'Scenario_may_010',
#  'Scenario_april_013',
#  'Scenario_january_007',
#  'Scenario_may_011',
#  'Scenario_may_006',
#  'Scenario_january_018',
#  'Scenario_november_015',
#  'Scenario_march_009',
#  'Scenario_june_008',
#  'Scenario_december_007',
#  'Scenario_may_025',
#  'Scenario_february_006',
#  'Scenario_april_025',
#  'Scenario_december_012',
#  'Scenario_august_012',
#  'Scenario_june_023',
#  'Scenario_september_010',
#  'Scenario_december_025',
#  'Scenario_may_008',
#  'Scenario_march_029',
#  'Scenario_october_007',
#  'Scenario_january_026',
#  'Scenario_august_004',
#  'Scenario_march_015',
#  'Scenario_november_024',
#  'Scenario_july_007',
#  'Scenario_january_019',
#  'Scenario_january_003',
#  'Scenario_december_025',
#  'Scenario_november_019',
#  'Scenario_may_029',
#  'Scenario_december_013',
#  'Scenario_february_002',
#  'Scenario_june_000',
#  'Scenario_september_002',
#  'Scenario_june_000',
#  'Scenario_march_002',
#  'Scenario_july_015',
#  'Scenario_july_003',
#  'Scenario_august_023',
#  'Scenario_february_018',
#  'Scenario_february_004',
#  'Scenario_october_009',
#  'Scenario_july_011',
#  'Scenario_june_016',
#  'Scenario_june_023',
#  'Scenario_december_028',
#  'Scenario_september_029',
#  'Scenario_november_015',
#  'Scenario_october_007',
#  'Scenario_july_001',
#  'Scenario_january_025',
#  'Scenario_december_011',
#  'Scenario_february_004',
#  'Scenario_may_004',
#  'Scenario_august_012',
#  'Scenario_march_012',
#  'Scenario_september_013',
#  'Scenario_june_010',
#  'Scenario_february_029',
#  'Scenario_december_007',
#  'Scenario_june_025',
#  'Scenario_september_005',
#  'Scenario_october_004',
#  'Scenario_october_011',
#  'Scenario_march_017',
#  'Scenario_july_004',
#  'Scenario_december_007',
#  'Scenario_august_013',
#  'Scenario_march_024',
#  'Scenario_january_028',
#  'Scenario_may_008',
#  'Scenario_april_020',
#  'Scenario_november_000',
#  'Scenario_august_000',
#  'Scenario_october_012',
#  'Scenario_february_024',
#  'Scenario_december_015',
#  'Scenario_may_020',
#  'Scenario_october_003',
#  'Scenario_february_012',
#  'Scenario_october_011',
#  'Scenario_november_019',
#  'Scenario_february_005',
#  'Scenario_september_013',
#  'Scenario_august_007',
#  'Scenario_december_026',
#  'Scenario_january_007',
#  'Scenario_august_014',
#  'Scenario_december_026',
#  'Scenario_february_000',
#  'Scenario_february_019',
#  'Scenario_july_015',
#  'Scenario_july_008',
#  'Scenario_november_007',
#  'Scenario_october_010']
