# %%
import os
import json
import string
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import grid2op
from grid2op.PlotGrid import PlotMatplot
from pprint import pprint

# %% [markdown]
# We will define here the topological actions we want to include in the LIPS benchmark for the l2rpn_neurips_2020_track1_small env.
#
# This is based on the "rl_agent" actions taken in the grid2viz demo (video: https://www.youtube.com/watch?v=xlqS-CzvMwk demo: https://grid2viz-neurips.herokuapp.com/)

# %% [markdown]
# ## Load ENV

# %%
# Defin ENV path
env_path = "l2rpn_case14_sandbox"

# %%
# Load ENV
env = grid2op.make(env_path)

# %%
env.backend.get_thermal_limit()
# Out:
# array([ 541.,  450.,  375.,  636.,  175.,  285.,  335.,  657.,  496.,
#         827.,  442.,  641.,  840.,  156.,  664.,  235.,  119.,  179.,
#        1986., 1572.], dtype=float32)

# %% [markdown]
# ## Line id finder

# %%
# To find lines
info_lines = {i:(l[0], l[1]) for i, l in enumerate(zip(env.line_or_to_subid, env.line_ex_to_subid))}

# %% [markdown]
# ## Plot grid

# %%
plot_helper = PlotMatplot(env.observation_space, 
                          sub_radius=14, 
                          load_radius=10, 
                          gen_radius=10,
                          width=950,
                          height=600,
                        )
plot_helper._line_bus_radius = 6
plot_helper._line_arrow_width = 10
plot_helper._line_arrow_len = 17


fig = plot_helper.plot_layout()
fig.show()
# Out:
# /tmp/ipykernel_623480/3959423837.py:14: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %% [markdown]
# ## Helper func to plot

# %%
def plot_action(action):
    obs = env.reset()
    obs, reward, done, info = env.step(env.action_space(action))
    fig_obs = plot_helper.plot_obs(obs, line_info=None, load_info=None, gen_info=None)
    print('Is ambigous??? -> {}'.format(info['is_ambiguous']))
    print('Exception => {}'.format(info['exception']))
    print()
    return fig_obs

# %%
action_sub={'set_bus':{'substations_id':[(4,(2,1,2,1,2))]}}#{'set_bus': {'loads_id': [(3, 2)], 'lines_or_id': [(17, 2)], 'lines_ex_id': [(6, 2)]}}
fig_obs = plot_action(action_sub)
fig_obs.show()
# Out:
# Is ambigous??? -> False
# Exception => []
# /tmp/ipykernel_623480/1300946933.py:3: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig_obs.show()

# %%
action_sub={'set_bus':{'substations_id':[(8,(2,1,1,2,2))]}}
fig_obs = plot_action(action_sub)
fig_obs.show()
# Out:
# Is ambigous??? -> False
# Exception => []
# /tmp/ipykernel_623480/3818815038.py:3: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig_obs.show()

# %%
action_sub={'set_bus':{'substations_id':[(3,(2,1,1,2,1,2))]}}
fig_obs = plot_action(action_sub)
fig_obs.show()
# Out:
# Is ambigous??? -> False
# Exception => []
# /tmp/ipykernel_623480/1855211360.py:3: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig_obs.show()

# %%
action_sub={'set_bus':{'substations_id':[(5,(1,1,2,2,1,2,2))]}}
fig_obs = plot_action(action_sub)
fig_obs.show()
# Out:
# Is ambigous??? -> False
# Exception => []
# /tmp/ipykernel_623480/3223349884.py:3: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig_obs.show()

# %%
action_sub={'set_bus':{'substations_id':[(1,(1,2,1,2,2,2))]}}
fig_obs = plot_action(action_sub)
fig_obs.show()
# Out:
# Is ambigous??? -> False
# Exception => []
# /tmp/ipykernel_623480/739643765.py:3: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig_obs.show()
